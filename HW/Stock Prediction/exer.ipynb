# %%
#Import the libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVR
plt.style.use('fivethirtyeight')

# %%
#Get the stock quote of apple stock market
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17') 
#Show the data 
df
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.629209
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.697079
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.838044
# 2012-01-06  15.098214  14.972143  14.991786  15.085714  318292800.0  12.972249
# 2012-01-09  15.276786  15.048214  15.196429  15.061786  394024400.0  12.951672
# ...               ...        ...        ...        ...          ...        ...
# 2019-12-11  67.775002  67.125000  67.202499  67.692497   78756800.0  66.899139
# 2019-12-12  68.139999  66.830002  66.945000  67.864998  137310400.0  67.069626
# 2019-12-13  68.824997  67.732498  67.864998  68.787498  133587600.0  67.981300
# 2019-12-16  70.197502  69.245003  69.250000  69.964996  128186000.0  69.144997
# 2019-12-17  70.442497  69.699997  69.892502  70.102501  114158400.0  69.280899
#
# ...

# %%
#Visualize the closing price history
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD ($)',fontsize=18)
plt.show()

# %% [markdown]
# EX. Create a new data frame with only the closing price and convert it to an array.
# Then create a variable to store the length of the training data set. I want the training data set to contain about 80% of the data.

# %%
#Create a new dataframe with only the 'Close' column
data = df.filter(['Close'])
#Converting the dataframe to a numpy array
dataset = data.values
#Get /Compute the number of rows to train the model on
training_data_len = math.ceil( len(dataset) *.8)
# Out:
# array([14.92964268])

# %% [markdown]
# Ex. Create a training data set that contains the past 60 day closing price values that we want to use to predict the 61st closing price value.
# So the first column in the ‘x_train’ data set will contain values from the data set from index 0 to index 59 (60 values total) and the second column will contain values from the data set from index 1 to index 60 (60 values) and so on and so forth.
# The ‘y_train’ data set will contain the 61st value located at index 60 for it’s first column and the 62nd value located at index 61 of the data set for it’s second value and so on and so forth.

# %%
???

# %%
#Convert x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# %% [markdown]
# Ex. create a SVR rbf model with C=100 and train it

# %%
???

# %% [markdown]
# EX. Create the test data and test the mean square error.
# put your prediction inside the variable predictions

# %%
???

# %% [markdown]
# Now you can visualize your result.
# run the next code segment and check that your result are close to the real world results.

# %%
#Plot/Create the data for the graph
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
#Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c1beac80e8e6> in <module>
#       2 train = data[:training_data_len]
#       3 valid = data[training_data_len:]
# ----> 4 valid['Predictions'] = predictions
#       5 #Visualize the data
#       6 plt.figure(figsize=(16,8))
#
# NameError: name 'predictions' is not defined

# %% [markdown]
# Best of Luck!
